# %%
import pandas as pd
from pycaret.time_series import *

# Load dataset (adjust path if needed)
df = pd.read_csv(
    "/Users/anuradhasrivastav/Documents/github/pycaret assignment/time_series_forecasting/delhiclimate.csv"
)

# Parse date and sort
df["date"] = pd.to_datetime(df["date"])
df = df.sort_values("date").set_index("date")
df.head()
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
# Target: temperature
y = df["meantemp"]

# Exogenous variables
X = df[["humidity", "wind_speed", "meanpressure"]]

print(y.shape, X.shape)
# Out:
# (1462,) (1462, 3)

# %%
df = pd.read_csv(
    "/Users/anuradhasrivastav/Documents/github/pycaret assignment/time_series_forecasting/delhiclimate.csv"
)

df["date"] = pd.to_datetime(df["date"])
df = df.sort_values("date").set_index("date")

# target + exogenous
y = df["meantemp"]
X = df[["humidity", "wind_speed", "meanpressure"]]

# %%
exp = setup(
    data=y,
    fh=30,
    fold=3,
    session_id=42,
    seasonal_period=365,
    use_gpu=False,
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_928cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_928cd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_928cd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_928cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_928cd_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_928cd_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_928cd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_928cd_row1_col1" class="data row1 col1" >meantemp</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_928cd_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_928cd_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_928cd_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_928cd_row3_col1" class="data row3 col1" >Not Present</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_928cd_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_928cd_row4_col1" class="data row4 col1" >(1462, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_928cd_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_928cd_row5_col1" class="data row5 col1" >(1462, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_928cd_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_928cd_row6_col1" class="data row6 col1" >(1432, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_928cd_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_928cd_row7_col1" class="data row7 col1" >(30, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_928cd_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_928cd_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_928cd_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_928cd_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_928cd_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_928cd_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_928cd_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_928cd_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_928cd_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_928cd_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_928cd_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_928cd_row13_col1" class="data row13 col1" >365</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_928cd_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_928cd_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_928cd_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_928cd_row15_col1" class="data row15 col1" >user_defined</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_928cd_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_928cd_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_928cd_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_928cd_row17_col1" class="data row17 col1" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_928cd_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_928cd_row18_col1" class="data row18 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_928cd_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_928cd_row19_col1" class="data row19 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_928cd_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_928cd_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_928cd_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_928cd_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_928cd_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_928cd_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_928cd_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_928cd_row23_col1" class="data row23 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_928cd_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_928cd_row24_col1" class="data row24 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_928cd_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_928cd_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_928cd_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_928cd_row26_col1" class="data row26 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_928cd_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_928cd_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_928cd_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_928cd_row28_col1" class="data row28 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_928cd_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_928cd_row29_col1" class="data row29 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_928cd_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_928cd_row30_col0" class="data ro

# %%
best = compare_models(sort="MASE")
final_model = finalize_model(best)
# Out:
# <style type="text/css">
# #T_28f44 th {
#   text-align: left;
# }
# #T_28f44_row0_col0, #T_28f44_row0_col7, #T_28f44_row1_col0, #T_28f44_row1_col1, #T_28f44_row1_col2, #T_28f44_row1_col3, #T_28f44_row1_col4, #T_28f44_row1_col5, #T_28f44_row1_col6, #T_28f44_row1_col7, #T_28f44_row2_col0, #T_28f44_row2_col1, #T_28f44_row2_col2, #T_28f44_row2_col3, #T_28f44_row2_col4, #T_28f44_row2_col5, #T_28f44_row2_col6, #T_28f44_row2_col7, #T_28f44_row3_col0, #T_28f44_row3_col1, #T_28f44_row3_col2, #T_28f44_row3_col3, #T_28f44_row3_col4, #T_28f44_row3_col5, #T_28f44_row3_col6, #T_28f44_row4_col0, #T_28f44_row4_col1, #T_28f44_row4_col2, #T_28f44_row4_col3, #T_28f44_row4_col4, #T_28f44_row4_col5, #T_28f44_row4_col6, #T_28f44_row4_col7, #T_28f44_row5_col0, #T_28f44_row5_col1, #T_28f44_row5_col2, #T_28f44_row5_col3, #T_28f44_row5_col4, #T_28f44_row5_col5, #T_28f44_row5_col6, #T_28f44_row5_col7, #T_28f44_row6_col0, #T_28f44_row6_col1, #T_28f44_row6_col2, #T_28f44_row6_col3, #T_28f44_row6_col4, #T_28f44_row6_col5, #T_28f44_row6_col6, #T_28f44_row6_col7, #T_28f44_row7_col0, #T_28f44_row7_col1, #T_28f44_row7_col2, #T_28f44_row7_col3, #T_28f44_row7_col4, #T_28f44_row7_col5, #T_28f44_row7_col6, #T_28f44_row7_col7, #T_28f44_row8_col0, #T_28f44_row8_col1, #T_28f44_row8_col2, #T_28f44_row8_col3, #T_28f44_row8_col4, #T_28f44_row8_col5, #T_28f44_row8_col6, #T_28f44_row8_col7, #T_28f44_row9_col0, #T_28f44_row9_col1, #T_28f44_row9_col2, #T_28f44_row9_col3, #T_28f44_row9_col4, #T_28f44_row9_col5, #T_28f44_row9_col6, #T_28f44_row9_col7, #T_28f44_row10_col0, #T_28f44_row10_col1, #T_28f44_row10_col2, #T_28f44_row10_col3, #T_28f44_row10_col4, #T_28f44_row10_col5, #T_28f44_row10_col6, #T_28f44_row10_col7, #T_28f44_row11_col0, #T_28f44_row11_col1, #T_28f44_row11_col2, #T_28f44_row11_col3, #T_28f44_row11_col4, #T_28f44_row11_col5, #T_28f44_row11_col6, #T_28f44_row11_col7, #T_28f44_row12_col0, #T_28f44_row12_col1, #T_28f44_row12_col2, #T_28f44_row12_col3, #T_28f44_row12_col4, #T_28f44_row12_col5, #T_28f44_row12_col6, #T_28f44_row12_col7, #T_28f44_row13_col0, #T_28f44_row13_col1, #T_28f44_row13_col2, #T_28f44_row13_col3, #T_28f44_row13_col4, #T_28f44_row13_col5, #T_28f44_row13_col6, #T_28f44_row13_col7, #T_28f44_row14_col0, #T_28f44_row14_col1, #T_28f44_row14_col2, #T_28f44_row14_col3, #T_28f44_row14_col4, #T_28f44_row14_col5, #T_28f44_row14_col6, #T_28f44_row14_col7, #T_28f44_row15_col0, #T_28f44_row15_col1, #T_28f44_row15_col2, #T_28f44_row15_col3, #T_28f44_row15_col4, #T_28f44_row15_col5, #T_28f44_row15_col6, #T_28f44_row15_col7, #T_28f44_row16_col0, #T_28f44_row16_col1, #T_28f44_row16_col2, #T_28f44_row16_col3, #T_28f44_row16_col4, #T_28f44_row16_col5, #T_28f44_row16_col6, #T_28f44_row16_col7, #T_28f44_row17_col0, #T_28f44_row17_col1, #T_28f44_row17_col2, #T_28f44_row17_col3, #T_28f44_row17_col4, #T_28f44_row17_col5, #T_28f44_row17_col6, #T_28f44_row17_col7, #T_28f44_row18_col0, #T_28f44_row18_col1, #T_28f44_row18_col2, #T_28f44_row18_col3, #T_28f44_row18_col4, #T_28f44_row18_col5, #T_28f44_row18_col6, #T_28f44_row18_col7, #T_28f44_row19_col0, #T_28f44_row19_col1, #T_28f44_row19_col2, #T_28f44_row19_col3, #T_28f44_row19_col4, #T_28f44_row19_col5, #T_28f44_row19_col6, #T_28f44_row19_col7, #T_28f44_row20_col0, #T_28f44_row20_col1, #T_28f44_row20_col2, #T_28f44_row20_col3, #T_28f44_row20_col4, #T_28f44_row20_col5, #T_28f44_row20_col6, #T_28f44_row20_col7, #T_28f44_row21_col0, #T_28f44_row21_col1, #T_28f44_row21_col2, #T_28f44_row21_col3, #T_28f44_row21_col4, #T_28f44_row21_col5, #T_28f44_row21_col6, #T_28f44_row21_col7, #T_28f44_row22_col0, #T_28f44_row22_col1, #T_28f44_row22_col2, #T_28f44_row22_col3, #T_28f44_row22_col4, #T_28f44_row22_col5, #T_28f44_row22_col6, #T_28f44_row22_col7, #T_28f44_row23_col0, #T_28f44_row23_col1, #T_28f44_row23_col2, #T_28f44_row23_col3, #T_28f44_row23_col4, #T_28f44_row23_col5, #T_28f44_row23_col6, #T_28f44_row23_col7, #T_28f44_row24_col0, #T_28f44_row24_col1, #T_28f44_row24_col2, #T_28f44_row24_col3, #T_28f44_row24_col4, #T_28f44_row24_col5, #T_28f44_row24_col6, #T_28f44_row24_col7 {
#   text-align: left;
# }
# #T_28f44_row0_col1, #T_28f44_row0_col2, #T_28f44_row0_col3, #T_28f44_row0_col4, #T_28f44_row0_col5, #T_28f44_row0_col6, #T_28f44_row3_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_28f44_row0_col8, #T_28f44_row1_col8, #T_28f44_row2_col8, #T_28f44_row3_col8, #T_28f44_row5_col8, #T_28f44_row6_col8, #T_28f44_row7_col8, #T_28f44_row8_col8, #T_28f44_row9_col8, #T_28f44_row10_col8, #T_28f44_row11_col8, #T_28f44_row12_col8, #T_28f44_row13_col8, #T_28f44_row14_col8, #T_28f44_row15_col8, #T_28f44_row16_col8, #T_28f44_row17_col8, #T_28f44_row18_col8, #T_28f44_row19_col8, #T_28f44_row20_col8, #T_28f44_row21_col8, #T_28f44_row22_col8, #T_28f44_row23_col8, #T_28f44_row24_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_28f44_row4_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_28f44">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28f44_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_28f44_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_28f44_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_28f44_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_28f44_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_28f44_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_28f44_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_28f44_level0_col7" class="col_heading level0 col7" >R2</th>
#       <th id="T_28f44_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28f44_level0_row0" class="row_heading level0 row0" >arima</th>
#       <td id="T_28f44_row0_col0" class="data row0 col0" >ARIMA</td>
#       <td id="T_28f44_row0_col1" class="data row0 col1" >1.8847</td>
#       <td id="T_28f44_row0_col2" class="data row0 col2" >1.6183</td>
#       <td id="T_28f44_row0_col3" class="data row0 col3" >2.3587</td>
#       <td id="T_28f44_row0_col4" class="data row0 col4" >2.7303</td>
#       <td id="T_28f44_row0_col5" class="data row0 col5" >0.0875</td>
#       <td id="T_28f44_row0_col6" class="data row0 col6" >0.0854</td>
#       <td id="T_28f44_row0_col7" class="data row0 col7" >-4.4741</td>
#       <td id="T_28f44_row0_col8" class="data row0 col8" >1.1467</td>
#     </tr>
#     <tr>
#       <th id="T_28f44_level0_row1" class="row_heading level0 row1" >naive</th>
#       <td id="T_28f44_row1_col0" class="data row1 col0" >Naive Forecaster</td>
#       <td id="T_28f44_row1_col1" class="data row1 col1" >1.9874</td>
#       <td id="T_28f44_row1_col2" class="data row1 col2" >1.6839</td>
#       <td id="T_28f44_row1_col3" class="data row1 col3" >2.4825</td>
#       <td id="T_28f44_row1_col4" class="data row1 col4" >2.8374</td>
#       <td id="T_28f44_row1_col5" class="data row1 col5" >0.0939</td>
#       <td id="T_28f44_row1_col6" class="data row1 col6" >0.0867</td>
#       <td id="T_28f44_row1_col7" class="data row1 col7" >-2.5564</td>
#       <td id="T_28f44_row1_col8" class="data row1 col8" >2.6067</td>
#     </tr>
#     <tr>
#       <th id="T_28f44_level0_row2" class="row_heading level0 row2" >gbr_cds_dt</th>
#       <td id="T_28f44_row2_col0" class="data row2 col0" >Gradient Boosting w/ Cond. Deseasonalize & Detrending</td>
#       <td id="T_28f44_row2_col1" class="data row2 col1" >2.0100</td>
#       <td id="T_28f44_row2_col2" class="data row2 col2" >1.6783</td>
#       <td id="T_28f44_row2_col3" class="data row2 col3" >2.5100</td>
#       <td id="T_28f44_row2_col4" class="data row2 col4" >2.8271</td>
#       <td id="T_28f44_row2_col5" class="data row2 col5" >0.0950</td>
#       <td id="T_28f44_row2_col6" class="data row2 col6" >0.0870</td>
#       <td id="T_28f44_row2_col7" class="data row2 col7" >-2.5517</td>
#       <td id="T_28f44_row2_col8" class="data row2 col8" >0.2233</td>
#     </tr>
#     <tr>
#       <th id="T_28f44_level0_row3"

# %%
last_date = df.index.max()   # last date in your original data
last_date
# Out:
# Timestamp('2017-01-01 00:00:00')

# %%
future_index = pd.date_range(start=last_date + pd.Timedelta(days=1),
                             periods=30,
                             freq="D")
future_index
# Out:
# DatetimeIndex(['2017-01-02', '2017-01-03', '2017-01-04', '2017-01-05',
#                '2017-01-06', '2017-01-07', '2017-01-08', '2017-01-09',
#                '2017-01-10', '2017-01-11', '2017-01-12', '2017-01-13',
#                '2017-01-14', '2017-01-15', '2017-01-16', '2017-01-17',
#                '2017-01-18', '2017-01-19', '2017-01-20', '2017-01-21',
#                '2017-01-22', '2017-01-23', '2017-01-24', '2017-01-25',
#                '2017-01-26', '2017-01-27', '2017-01-28', '2017-01-29',
#                '2017-01-30', '2017-01-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
# take the last row of exogenous vars
last_exog = X.iloc[[-1]].copy()  # shape (1, 3)

# repeat it 30 times to match future_index
future_exog = pd.concat([last_exog] * 30, ignore_index=True)
future_exog.index = future_index

future_exog.head()
# Out:
#             humidity  wind_speed  meanpressure
# 2017-01-02     100.0         0.0        1016.0
# 2017-01-03     100.0         0.0        1016.0
# 2017-01-04     100.0         0.0        1016.0
# 2017-01-05     100.0         0.0        1016.0
# 2017-01-06     100.0         0.0        1016.0

# %%
forecast = predict_model(
    final_model,
    fh=30,
    X=future_exog   # 👈 this is the key change
)
forecast.head(10)
# Out:
# ---------------------------------------------------------------------------
# InvalidComparison                         Traceback (most recent call last)
# File ~/Documents/github/pycaret assignment/.venv-pycaret3/lib/python3.11/site-packages/pandas/core/arrays/datetimelike.py:941, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#     940 try:
# --> 941     other = self._validate_comparison_value(other)
#     942 except InvalidComparison:
#
# File ~/Documents/github/pycaret assignment/.venv-pycaret3/lib/python3.11/site-packages/pandas/core/arrays/datetimelike.py:537, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     536 elif not is_list_like(other):
# --> 537     raise InvalidComparison(other)
#     539 elif len(other) != len(self):
#
# InvalidComparison: 2017-01-01
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 forecast = predict_model(
#       2     final_model,
#       3     fh=30,
#       4     X=future_exog   # 👈 this is the key change
#       5 )
#       6 forecast.head(10)
#
# File ~/Documents/github/pycaret assignment/.venv-pycaret3/lib/python3.11/site-packages/pycaret/time_series/forecasting/functional.py:1492, in predict_model(estimator, fh, X, return_pred_int, alpha, coverage, round, verbose)
#    1489 if experiment is None:
#    1490     experiment = _EXPERIMENT_CLASS()
# -> 1492 return experiment.predict_model(
#    1493     estimator=estimator,
#    1494     fh=fh,
#    1495     X=X,
#    1496     return_pred_int=return_pred_int,
#    1497     alpha=alpha,
#    1498     coverage=coverage,
#    1499     round=round,
#    1500     verbose=verbose,
#    1501 )
#
# File ~/Documents/github/pycaret assignment/.venv-pycaret3/lib/python3.11/site-packages/pycaret/time_series/forecasting/oop.py:4567, in TSForecastingExperiment.predict_model(self, estimator, fh, X, return_pred_int, alpha, coverage, round, verbose)
#    4564 fh = self._predict_model_reconcile_fh(estimator=estimator_, fh=fh)
#    4565 X = self._predict_model_reconcile_X(estimator=estimator_, X=X)
# -> 4567 result = get_predictions_with_intervals(
#    4568     forecaster=pipeline_with_model,
#    4569     alpha=alpha,
#    4570     coverage=coverage,
#    4571     X=X,
#    4572     fh=fh,
#    4573     merge=True,
#    4574     round=round,
#    4575 )
#    4576 y_pred = pd.DataFrame(result["y_pred"])
#    4578 #################
#    4579 # Metrics ####
#    4580 #################
#
# File ~/Documents/github/pycaret assignment/.venv-pycaret3/lib/python3.11/site-packages/pycaret/utils/time_series/forecasting/__init__.py:110, in get_predictions_with_intervals(forecaster, alpha, coverage, X, fh, merge, round)
#     108 # Get Point predictions ----
#     109 if alpha is None:
# --> 110     y_pred = forecaster.predict(fh=fh, X=X)
#     111     y_pred = pd.DataFrame({"y_pred": y_pred})
#     112 else:
#
# File ~/Documents/github/pycaret assignment/.venv-pycaret3/lib/python3.11/site-packages/sktime/forecasting/base/_base.py:431, in BaseForecaster.predict(self, fh, X)
#     429 # we call the ordinary _predict if no looping/vectorization needed
#     430 if not self._is_vectorized:
# --> 431     y_pred = self._predict(fh=fh, X=X_inner)
#     432 else:
#     433     # otherwise we call the vectorized version of predict
#     434     y_pred = self._vectorize("predict", X=X_inner, fh=fh)
#
# File ~/Documents/github/pycaret assignment/.venv-pycaret3/lib/python3.11/site-packages/sktime/forecasting/compose/_pipeline.py:521, in ForecastingPipeline._predict(self, fh, X)
#     506 """Forecast time series at future horizon.
#     507
#     508 Parameters
#    (...)    518     Point predictions
#     519 """
#     520 X = self._transform(X=X, y=fh)
# --> 521 return self.forecaster_.predict(fh, X)
#
# File ~/Documents/github/pycaret assignment/.venv-pycaret3/lib/python3.11/site-packages/sktime/forecasting/base/_base.py:431, in BaseForecaster.predict(self, fh, X)
#     429 # we call the ordinary _predict if no looping/vectorization needed
#     430 if not self._is_vectorized:
# --> 431     y_pred = self._predict(fh=fh, X=X_inner)
#     432 else:
#     433     # otherwise we call the vectorized version of predict
#     434     y_pred = self._vectorize("predict", X=X_inner, fh=fh)
#
# File ~/Documents/github/pycaret assignment/.venv-pycaret3/lib/python3.11/site-packages/sktime/forecasting/compose/_pipeline.py:1032, in TransformedTargetForecaster._predict(self, fh, X)
#    1017 def _predict(self, fh=None, X=None):
#    1018     """Forecast time series at future horizon.
#    1019
#    1020     Parameters
#    (...)   1030         Point predictions
#    1031     """
# -> 1032     y_pred = self.forecaster_.predict(fh=fh, X=X)
#    1033     # inverse transform y_pred
#    1034     y_pred = self._get_inverse_transform(self.transformers_pre_, y_pred, X)
#
# File ~/Documents/github/pycaret assignment/.venv-pycaret3/lib/python3.11/site-packages/sktime/forecasting/base/_base.py:431, in BaseForecaster.predict(self, fh, X)
#     429 # we call the ordinary _predict if no looping/vectorization needed
#     430 if not self._is_vectorized:
# --> 431     y_pred = self._predict(fh=fh, X=X_inner)
#     432 else:
#     433     # otherwise we call the vectorized version of predict
#     434     y_pred = self._vectorize("predict", X=X_inner, fh=fh)
#
# File ~/Documents/github/pycaret assignment/.venv-pycaret3/lib/python3.11/site-packages/sktime/forecasting/base/adapters/_pmdarima.py:99, in _PmdArimaAdapter._predict(self, fh, X)
#      96 # +2 because + 1 for "end" (python index), +1 for starting to count at 1 in fh
#      98 if X is not None:
# ---> 99     X = get_slice(X, start=self.cutoff[0], start_inclusive=False)
#     100     X = X.iloc[:end_int]
#     102 # distinguish between in-sample and out-of-sample prediction
#
# File ~/Documents/github/pycaret assignment/.venv-pycaret3/lib/python3.11/site-packages/sktime/datatypes/_utilities.py:609, in get_slice(obj, start, end, start_inclusive, end_inclusive)
#     607     slice_select = get_end_cond()
#     608 elif start:
# --> 609     slice_select = get_start_cond()
#     611 obj_subset = obj.iloc[slice_select]
#     612 return convert_to(obj_subset, obj_in_mtype)
#
# File ~/Documents/github/pycaret assignment/.venv-pycaret3/lib/python3.11/site-packages/sktime/datatypes/_utilities.py:596, in get_slice.<locals>.get_start_cond()
#     594     return time_indices >= start
#     595 else:
# --> 596     return time_indices > start
#
# File ~/Documents/github/pycaret assignment/.venv-pycaret3/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/Documents/github/pycaret assignment/.venv-pycaret3/lib/python3.11/site-packages/pandas/core/arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~/Documents/github/pycaret assignment/.venv-pycaret3/lib/python3.11/site-packages/pandas/core/indexes/base.py:7125, in Index._cmp_method(self, other, op)
#    7122     result = op(self._values, other)
#    7124 elif isinstance(self._values, ExtensionArray):
# -> 7125     result = op(self._values, other)
#    7127 elif is_object_dtype(self.dtype) and not isinstance(self, ABCMultiIndex):
#    7128     # don't pass MultiIndex
#    7129     result = ops.comp_method_OBJECT_ARRAY(op, self._values, other)
#
# File ~/Documents/github/pycaret assignment/.venv-pycaret3/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/Documents/github/pycaret assignment/.venv-pycaret3/lib/python3.11/site-packages/pandas/core/arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~/Documents/github/pycaret assignment/.venv-pycaret3/lib/python3.11/site-packages/pandas/core/arrays/datetimelike.py:943, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#     941     other = self._validate_comparison_value(other)
#     942 except InvalidComparison:
# --> 943     return invalid_comparison(self, other, op)
#     945 dtype = getattr(other, "dtype", None)
#     946 if is_object_dtype(dtype):
#     947     # We have to use comp_method_OBJECT_ARRAY instead of numpy
#     948     #  comparison otherwise it would raise when comparing to None
#
# File ~/Documents/github/pycaret assignment/.venv-pycaret3/lib/python3.11/site-packages/pandas/core/ops/invalid.py:40, in invalid_comparison(left, right, op)
#      38 else:
#      39     typ = type(right).__name__
# ---> 40     raise TypeError(f"Invalid comparison between dtype={left.dtype} and {typ}")
#      41 return res_values
#
# TypeError: Invalid comparison between dtype=datetime64[ns] and Period

# %%
from pycaret.time_series import get_config

y_train = get_config("y_train")
print(type(y_train.index))
print(y_train.index[:5])
# Out:
# <class 'pandas.core.indexes.period.PeriodIndex'>
# PeriodIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#              '2013-01-05'],
#             dtype='period[D]', name='date')

# %%
# 1. last date we have
last_date = df.index.max()               # e.g. 2017-01-01

# 2. make 30 future DAILY dates
future_index = pd.date_range(
    start=last_date + pd.Timedelta(days=1),
    periods=30,
    freq="D"
)

# 3. take last known exog row
last_exog = X.iloc[[-1]].copy()          # shape (1, 3)

# 4. repeat it 30 times
future_exog = pd.concat([last_exog] * 30, ignore_index=True)

# 5. set the datetime index first
future_exog.index = future_index

# 6. convert to PeriodIndex (D) to match PyCaret
future_exog.index = future_exog.index.to_period("D")

future_exog.head()
# Out:
#             humidity  wind_speed  meanpressure
# 2017-01-02     100.0         0.0        1016.0
# 2017-01-03     100.0         0.0        1016.0
# 2017-01-04     100.0         0.0        1016.0
# 2017-01-05     100.0         0.0        1016.0
# 2017-01-06     100.0         0.0        1016.0

# %%
forecast = predict_model(
    final_model,
    fh=30,
    X=future_exog
)

forecast.head(10)
# Out:
#              y_pred
# 2017-01-02  10.3473
# 2017-01-03  10.6865
# 2017-01-04  11.0175
# 2017-01-05  11.3408
# 2017-01-06  11.6564
# 2017-01-07  11.9645
# 2017-01-08  12.2653
# 2017-01-09  12.5590
# 2017-01-10  12.8457
# 2017-01-11  13.1257
