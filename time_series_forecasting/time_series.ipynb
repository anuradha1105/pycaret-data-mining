# %%
import pandas as pd
from pycaret.time_series import *

# Load your dataset (adjust path if needed)
df = pd.read_csv("../time_series_forecasting/delhiclimate.csv")

# View a few rows
df.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df.columns
# Out:
# Index(['date', 'meantemp', 'humidity', 'wind_speed', 'meanpressure'], dtype='object')

# %%
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date')

# Let's forecast temperature
series = df['meantemp']
series.head()
# Out:
# date
# 2013-01-01    10.000000
# 2013-01-02     7.400000
# 2013-01-03     7.166667
# 2013-01-04     8.666667
# 2013-01-05     6.000000
# Name: meantemp, dtype: float64

# %%
exp = setup(
    data=series,
    fold=3,
    fh=7,                # forecast horizon (7 days)
    session_id=42,
    seasonal_period=365, # daily data with yearly seasonality
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d7b0d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7b0d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d7b0d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7b0d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d7b0d_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_d7b0d_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d7b0d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d7b0d_row1_col1" class="data row1 col1" >meantemp</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d7b0d_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_d7b0d_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d7b0d_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_d7b0d_row3_col1" class="data row3 col1" >Not Present</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d7b0d_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_d7b0d_row4_col1" class="data row4 col1" >(1462, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d7b0d_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_d7b0d_row5_col1" class="data row5 col1" >(1462, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d7b0d_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_d7b0d_row6_col1" class="data row6 col1" >(1455, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d7b0d_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_d7b0d_row7_col1" class="data row7 col1" >(7, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d7b0d_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_d7b0d_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d7b0d_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_d7b0d_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d7b0d_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_d7b0d_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d7b0d_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_d7b0d_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d7b0d_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_d7b0d_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d7b0d_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_d7b0d_row13_col1" class="data row13 col1" >365</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d7b0d_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_d7b0d_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d7b0d_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_d7b0d_row15_col1" class="data row15 col1" >user_defined</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d7b0d_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_d7b0d_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d7b0d_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_d7b0d_row17_col1" class="data row17 col1" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d7b0d_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_d7b0d_row18_col1" class="data row18 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d7b0d_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_d7b0d_row19_col1" class="data row19 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d7b0d_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_d7b0d_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d7b0d_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_d7b0d_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d7b0d_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_d7b0d_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_d7b0d_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_d7b0d_row23_col1" class="data row23 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_d7b0d_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_d7b0d_row24_col1" class="data row24 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_d7b0d_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_d7b0d_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_d7b0d_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_d7b0d_row26_col1" class="data row26 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_d7b0d_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_d7b0d_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_d7b0d_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_d7b0d_row28_col1" class="data row28 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_d7b0d_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_d7b0d_row29_col1" class="data row29 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d7b0d_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_d7b0d_row30_col0" class="data row

# %%
best_model = compare_models(sort='MASE')
# Out:
# <style type="text/css">
# #T_ee934 th {
#   text-align: left;
# }
# #T_ee934_row0_col0, #T_ee934_row1_col0, #T_ee934_row1_col1, #T_ee934_row1_col2, #T_ee934_row1_col3, #T_ee934_row1_col4, #T_ee934_row1_col5, #T_ee934_row1_col6, #T_ee934_row1_col7, #T_ee934_row2_col0, #T_ee934_row2_col1, #T_ee934_row2_col2, #T_ee934_row2_col3, #T_ee934_row2_col4, #T_ee934_row2_col5, #T_ee934_row2_col6, #T_ee934_row2_col7, #T_ee934_row3_col0, #T_ee934_row3_col1, #T_ee934_row3_col2, #T_ee934_row3_col3, #T_ee934_row3_col4, #T_ee934_row3_col5, #T_ee934_row3_col6, #T_ee934_row3_col7, #T_ee934_row4_col0, #T_ee934_row4_col1, #T_ee934_row4_col2, #T_ee934_row4_col3, #T_ee934_row4_col4, #T_ee934_row4_col5, #T_ee934_row4_col6, #T_ee934_row4_col7, #T_ee934_row5_col0, #T_ee934_row5_col1, #T_ee934_row5_col2, #T_ee934_row5_col3, #T_ee934_row5_col4, #T_ee934_row5_col5, #T_ee934_row5_col6, #T_ee934_row5_col7, #T_ee934_row6_col0, #T_ee934_row6_col1, #T_ee934_row6_col2, #T_ee934_row6_col3, #T_ee934_row6_col4, #T_ee934_row6_col5, #T_ee934_row6_col6, #T_ee934_row6_col7, #T_ee934_row7_col0, #T_ee934_row7_col1, #T_ee934_row7_col2, #T_ee934_row7_col3, #T_ee934_row7_col4, #T_ee934_row7_col5, #T_ee934_row7_col6, #T_ee934_row7_col7, #T_ee934_row8_col0, #T_ee934_row8_col1, #T_ee934_row8_col2, #T_ee934_row8_col3, #T_ee934_row8_col4, #T_ee934_row8_col5, #T_ee934_row8_col6, #T_ee934_row8_col7, #T_ee934_row9_col0, #T_ee934_row9_col1, #T_ee934_row9_col2, #T_ee934_row9_col3, #T_ee934_row9_col4, #T_ee934_row9_col5, #T_ee934_row9_col6, #T_ee934_row9_col7, #T_ee934_row10_col0, #T_ee934_row10_col1, #T_ee934_row10_col2, #T_ee934_row10_col3, #T_ee934_row10_col4, #T_ee934_row10_col5, #T_ee934_row10_col6, #T_ee934_row10_col7, #T_ee934_row11_col0, #T_ee934_row11_col1, #T_ee934_row11_col2, #T_ee934_row11_col3, #T_ee934_row11_col4, #T_ee934_row11_col5, #T_ee934_row11_col6, #T_ee934_row11_col7, #T_ee934_row12_col0, #T_ee934_row12_col1, #T_ee934_row12_col2, #T_ee934_row12_col3, #T_ee934_row12_col4, #T_ee934_row12_col5, #T_ee934_row12_col6, #T_ee934_row12_col7, #T_ee934_row13_col0, #T_ee934_row13_col1, #T_ee934_row13_col2, #T_ee934_row13_col3, #T_ee934_row13_col4, #T_ee934_row13_col5, #T_ee934_row13_col6, #T_ee934_row13_col7, #T_ee934_row14_col0, #T_ee934_row14_col1, #T_ee934_row14_col2, #T_ee934_row14_col3, #T_ee934_row14_col4, #T_ee934_row14_col5, #T_ee934_row14_col6, #T_ee934_row14_col7, #T_ee934_row15_col0, #T_ee934_row15_col1, #T_ee934_row15_col2, #T_ee934_row15_col3, #T_ee934_row15_col4, #T_ee934_row15_col5, #T_ee934_row15_col6, #T_ee934_row15_col7, #T_ee934_row16_col0, #T_ee934_row16_col1, #T_ee934_row16_col2, #T_ee934_row16_col3, #T_ee934_row16_col4, #T_ee934_row16_col5, #T_ee934_row16_col6, #T_ee934_row16_col7, #T_ee934_row17_col0, #T_ee934_row17_col1, #T_ee934_row17_col2, #T_ee934_row17_col3, #T_ee934_row17_col4, #T_ee934_row17_col5, #T_ee934_row17_col6, #T_ee934_row17_col7, #T_ee934_row18_col0, #T_ee934_row18_col1, #T_ee934_row18_col2, #T_ee934_row18_col3, #T_ee934_row18_col4, #T_ee934_row18_col5, #T_ee934_row18_col6, #T_ee934_row18_col7, #T_ee934_row19_col0, #T_ee934_row19_col1, #T_ee934_row19_col2, #T_ee934_row19_col3, #T_ee934_row19_col4, #T_ee934_row19_col5, #T_ee934_row19_col6, #T_ee934_row19_col7, #T_ee934_row20_col0, #T_ee934_row20_col1, #T_ee934_row20_col2, #T_ee934_row20_col3, #T_ee934_row20_col4, #T_ee934_row20_col5, #T_ee934_row20_col6, #T_ee934_row20_col7, #T_ee934_row21_col0, #T_ee934_row21_col1, #T_ee934_row21_col2, #T_ee934_row21_col3, #T_ee934_row21_col4, #T_ee934_row21_col5, #T_ee934_row21_col6, #T_ee934_row21_col7, #T_ee934_row22_col0, #T_ee934_row22_col1, #T_ee934_row22_col2, #T_ee934_row22_col3, #T_ee934_row22_col4, #T_ee934_row22_col5, #T_ee934_row22_col6, #T_ee934_row22_col7, #T_ee934_row23_col0, #T_ee934_row23_col1, #T_ee934_row23_col2, #T_ee934_row23_col3, #T_ee934_row23_col4, #T_ee934_row23_col5, #T_ee934_row23_col6, #T_ee934_row23_col7, #T_ee934_row24_col0, #T_ee934_row24_col1, #T_ee934_row24_col2, #T_ee934_row24_col3, #T_ee934_row24_col4, #T_ee934_row24_col5, #T_ee934_row24_col6, #T_ee934_row24_col7 {
#   text-align: left;
# }
# #T_ee934_row0_col1, #T_ee934_row0_col2, #T_ee934_row0_col3, #T_ee934_row0_col4, #T_ee934_row0_col5, #T_ee934_row0_col6, #T_ee934_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ee934_row0_col8, #T_ee934_row1_col8, #T_ee934_row3_col8, #T_ee934_row4_col8, #T_ee934_row5_col8, #T_ee934_row6_col8, #T_ee934_row7_col8, #T_ee934_row8_col8, #T_ee934_row9_col8, #T_ee934_row10_col8, #T_ee934_row11_col8, #T_ee934_row12_col8, #T_ee934_row13_col8, #T_ee934_row14_col8, #T_ee934_row15_col8, #T_ee934_row16_col8, #T_ee934_row17_col8, #T_ee934_row18_col8, #T_ee934_row19_col8, #T_ee934_row20_col8, #T_ee934_row21_col8, #T_ee934_row22_col8, #T_ee934_row23_col8, #T_ee934_row24_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ee934_row2_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ee934">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee934_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ee934_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_ee934_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_ee934_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_ee934_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_ee934_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_ee934_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_ee934_level0_col7" class="col_heading level0 col7" >R2</th>
#       <th id="T_ee934_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee934_level0_row0" class="row_heading level0 row0" >knn_cds_dt</th>
#       <td id="T_ee934_row0_col0" class="data row0 col0" >K Neighbors w/ Cond. Deseasonalize & Detrending</td>
#       <td id="T_ee934_row0_col1" class="data row0 col1" >1.1306</td>
#       <td id="T_ee934_row0_col2" class="data row0 col2" >1.0498</td>
#       <td id="T_ee934_row0_col3" class="data row0 col3" >1.3944</td>
#       <td id="T_ee934_row0_col4" class="data row0 col4" >1.7478</td>
#       <td id="T_ee934_row0_col5" class="data row0 col5" >0.0801</td>
#       <td id="T_ee934_row0_col6" class="data row0 col6" >0.0803</td>
#       <td id="T_ee934_row0_col7" class="data row0 col7" >-0.4959</td>
#       <td id="T_ee934_row0_col8" class="data row0 col8" >0.1167</td>
#     </tr>
#     <tr>
#       <th id="T_ee934_level0_row1" class="row_heading level0 row1" >ada_cds_dt</th>
#       <td id="T_ee934_row1_col0" class="data row1 col0" >AdaBoost w/ Cond. Deseasonalize & Detrending</td>
#       <td id="T_ee934_row1_col1" class="data row1 col1" >1.1892</td>
#       <td id="T_ee934_row1_col2" class="data row1 col2" >1.0900</td>
#       <td id="T_ee934_row1_col3" class="data row1 col3" >1.4666</td>
#       <td id="T_ee934_row1_col4" class="data row1 col4" >1.8148</td>
#       <td id="T_ee934_row1_col5" class="data row1 col5" >0.0844</td>
#       <td id="T_ee934_row1_col6" class="data row1 col6" >0.0849</td>
#       <td id="T_ee934_row1_col7" class="data row1 col7" >-0.5711</td>
#       <td id="T_ee934_row1_col8" class="data row1 col8" >0.1633</td>
#     </tr>
#     <tr>
#       <th id="T_ee934_level0_row2" class="row_heading level0 row2" >theta</th>
#       <td id="T_ee934_row2_col0" class="data row2 col0" >Theta Forecaster</td>
#       <td id="T_ee934_row2_col1" class="data row2 col1" >1.2369</td>
#       <td id="T_ee934_row2_col2" class="data row2 col2" >1.1024</td>
#       <td id="T_ee934_row2_col3" class="data row2 col3" >1.5256</td>
#       <td id="T_ee934_row2_col4" class="data row2 col4" >1.8356</td>
#       <td id="T_ee934_row2_col5" class="data row2 col5" >0.0892</td>
#       <td id="T_ee934_row2_col6" class="data row2 col6" >0.0862</td>
#       <td id="T_ee934_row2_col7" class="data row2 col7" >-0.7004</td>
#       <td id="T_ee934_row2_col8" class="data row2 col8" >0.0333</td>
#     </tr>
#     <t

# %%
final_model = finalize_model(best_model)

future_forecast = predict_model(final_model, fh=30)  # forecast 30 days ahead
print(future_forecast)
# Out:
#              y_pred
# 2017-01-02  11.5096
# 2017-01-03  11.4938
# 2017-01-04  11.4961
# 2017-01-05  11.4984
# 2017-01-06  11.5007
# 2017-01-07  11.5029
# 2017-01-08  11.5052
# 2017-01-09  11.5075
# 2017-01-10  11.5097
# 2017-01-11  11.5120
# 2017-01-12  11.5143
# 2017-01-13  11.5165
# 2017-01-14  11.5188
# 2017-01-15  11.5211
# 2017-01-16  11.5234
# 2017-01-17  11.5256
# 2017-01-18  11.5279
# 2017-01-19  11.5302
# 2017-01-20  11.5324
# 2017-01-21  11.5347
# 2017-01-22  11.5370
# 2017-01-23  11.5393
# 2017-01-24  11.5415
# 2017-01-25  11.5438
# 2017-01-26  11.5461
# 2017-01-27  11.5483
# 2017-01-28  11.5506
# 2017-01-29  11.5529
# 2017-01-30  11.5551
# 2017-01-31  11.5574

# %%
future_forecast.to_csv("forecast_output.csv", index=False)
print("Forecast saved as forecast_output.csv")
# Out:
# Forecast saved as forecast_output.csv

# %%
plot_model(final_model, plot='forecast')
plot_model(final_model, plot='diagnostics')
# Out:
# In sample predictions has not been implemented for this estimator of type 'ForecastingPipeline' in `sktime`. When this is implemented, it will be enabled by default in pycaret.
# In sample predictions has not been implemented for this estimator of type 'ForecastingPipeline' in `sktime`. When this is implemented, it will be enabled by default in pycaret.
