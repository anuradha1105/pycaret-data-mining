# %%
import sys
sys.executable
# Out:
# '/Users/anuradhasrivastav/Documents/github/pycaret assignment/.venv-pycaret2/bin/python'

# %%
from pycaret.arules import *

# %%
from pycaret.arules import *
print("pycaret.arules imported ✅")
# Out:
# pycaret.arules imported ✅

# %%
import pandas as pd

data = {
    "InvoiceNo": [1, 1, 1, 2, 2, 3],
    "Description": ["milk", "bread", "eggs", "bread", "butter", "milk"],
}
df = pd.DataFrame(data)

exp = setup(
    data=df,
    transaction_id="InvoiceNo",
    item_id="Description",
    session_id=123,
)

rules = create_model(metric="confidence", threshold=0.3)
rules.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_ca905_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ca905_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_ca905_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <td id="T_ca905_row1_col0" class="data row1 col0" ># Transactions</td>
#       <td id="T_ca905_row1_col1" class="data row1 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_ca905_row2_col0" class="data row2 col0" ># Items</td>
#       <td id="T_ca905_row2_col1" class="data row2 col1" >4</td>
#     </tr>
#     <tr>
#       <td id="T_ca905_row3_col0" class="data row3 col0" >Ignore Items</td>
#       <td id="T_ca905_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
import pandas as pd

data = {
    "InvoiceNo": [1, 1, 1, 2, 2, 3],
    "Description": ["milk", "bread", "eggs", "bread", "butter", "milk"],
}
df = pd.DataFrame(data)

exp = setup(
    data=df,
    transaction_id="InvoiceNo",
    item_id="Description",
    session_id=123,
)

rules = create_model(metric="confidence", threshold=0.3)
rules.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_69a5b_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_69a5b_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_69a5b_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <td id="T_69a5b_row1_col0" class="data row1 col0" ># Transactions</td>
#       <td id="T_69a5b_row1_col1" class="data row1 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_69a5b_row2_col0" class="data row2 col0" ># Items</td>
#       <td id="T_69a5b_row2_col1" class="data row2 col1" >4</td>
#     </tr>
#     <tr>
#       <td id="T_69a5b_row3_col0" class="data row3 col0" >Ignore Items</td>
#       <td id="T_69a5b_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
import pandas as pd

df = pd.read_csv("./Groceries_dataset.csv")   # go one folder up from the notebook into data/
df.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
from pycaret.arules import *

exp = setup(
    data=df,
    transaction_id="Member_number",   #  change to match your column names
    item_id="itemDescription",
    session_id=123,
)

rules = create_model(metric="confidence", threshold=0.3)
rules.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_f23e7_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f23e7_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_f23e7_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <td id="T_f23e7_row1_col0" class="data row1 col0" ># Transactions</td>
#       <td id="T_f23e7_row1_col1" class="data row1 col1" >3898</td>
#     </tr>
#     <tr>
#       <td id="T_f23e7_row2_col0" class="data row2 col0" ># Items</td>
#       <td id="T_f23e7_row2_col1" class="data row2 col1" >167</td>
#     </tr>
#     <tr>
#       <td id="T_f23e7_row3_col0" class="data row3 col0" >Ignore Items</td>
#       <td id="T_f23e7_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
print(df.columns)
# Out:
# Index(['Member_number', 'Date', 'itemDescription'], dtype='object')

# %%
# PyCaret Association Rule Mining (PyCaret 2.3.5)
- environment: .venv-pycaret2 (Python 3.8.18)
- dataset: groceries.csv (transactions: Member_number, itemDescription)
- steps: setup → create_model → view rules
